# %% [markdown]
# # 0 Packages & Functions

# %%
import pandas as pd

# %% [markdown]
# # 1. Quantitative

# %% [markdown]
# ## 1.1. Events

# %% [markdown]
# ### Extreme Weather US

# %%
Extreme_Weather_Events_US = pd.read_csv("events-US-1980-2023.csv").reset_index()
Extreme_Weather_Events_US.columns = list(Extreme_Weather_Events_US.loc[0])
Extreme_Weather_Events_US = Extreme_Weather_Events_US.drop([0]).reset_index(drop = True)

#Transform the dates to actual date type
Extreme_Weather_Events_US["Begin Date"] = pd.to_datetime(Extreme_Weather_Events_US["Begin Date"], format="%Y%m%d")
Extreme_Weather_Events_US["End Date"] = pd.to_datetime(Extreme_Weather_Events_US["Begin Date"], format="%Y%m%d")

#only select events that started after or in 2016 and ended before or in 2020
Extreme_Weather_Events_US = Extreme_Weather_Events_US[(Extreme_Weather_Events_US["Begin Date"].dt.year >= 2016) & 
                          (Extreme_Weather_Events_US["End Date"].dt.year <= 2020)].reset_index(drop = True)

#transform string of numbers to numbers
Extreme_Weather_Events_US["Deaths"] = pd.to_numeric(Extreme_Weather_Events_US["Deaths"], downcast='integer')
Extreme_Weather_Events_US["Total CPI-Adjusted Cost (Millions of Dollars)"] = pd.to_numeric(Extreme_Weather_Events_US["Total CPI-Adjusted Cost (Millions of Dollars)"], downcast='integer')

Extreme_Weather_Events_US
# Out:
#                                                  Name          Disaster  \
# 0     Southeast and Eastern Tornadoes (February 2016)      Severe Storm
# 1           Texas and Louisiana Flooding (March 2016)          Flooding
# 2                Southern Severe Weather (March 2016)      Severe Storm
# 3                 North Texas Hail Storm (March 2016)      Severe Storm
# 4         North/Central Texas Hail Storm (April 2016)      Severe Storm
# ..                                                ...               ...
# 81                     Hurricane Delta (October 2020)  Tropical Cyclone
# 82                      Hurricane Zeta (October 2020)  Tropical Cyclone
# 83                 Tropical Storm Eta (November 2020)  Tropical Cyclone
# 84  Western Wildfires - California, Oregon, Washin...          Wildfire
# 85  Western/Central Drought and Heat Wave (Summer-...           Drought
#
#    Begin Date   End Date  Total CPI-Adjusted Cost (Millions of Dollars)  \
# 0  2016-02-22 2016-02-22                                         1320.7
# 1  2016-03-08 2016-03-08                                         2914.4
# 2  2016-03-17 2016-03-17                                         1537.1
# 3  2016-03-23 2016-03-23                                         2622.2
# 4  2016-04-10 2016-04-10                                         4408.2
# ..        ...        ...                                            ...
# 81 2020-10-09 2020-10-09                                         3325.7
# 82 2020-10-28 2020-10-28                                         5048.3
# 83 2020-11-08 2020-11-08                                         1693.6
# 84 2020-08-01 2020-08-01                                        19082.0
# 85 2020-06-01 2020-06-01                                         5214.2
#
#     Deaths
# 0       10
# 1        5
# 2        1
# 3        0
# 4        0
# ..     ...
# 81       5
# 82       6
# 83      12
# 84      46
# 85      45
#
# [86 rows x 6 columns]

# %%
#Look at the events with the highest amount of deaths (Size)
Extreme_Weather_Events_US.sort_values(by = "Deaths", ascending = False).head(10)
# Out:
#                                                  Name          Disaster  \
# 31                   Hurricane Maria (September 2017)  Tropical Cyclone
# 49  Western Wildfires, California Firestorm (Summe...          Wildfire
# 30                    Hurricane Irma (September 2017)  Tropical Cyclone
# 29                     Hurricane Harvey (August 2017)  Tropical Cyclone
# 33  Western Wildfires, California Firestorm (Summe...          Wildfire
# 46                Hurricane Florence (September 2018)  Tropical Cyclone
# 12                   Hurricane Matthew (October 2016)  Tropical Cyclone
# 47                   Hurricane Michael (October 2018)  Tropical Cyclone
# 84  Western Wildfires - California, Oregon, Washin...          Wildfire
# 85  Western/Central Drought and Heat Wave (Summer-...           Drought
#
#    Begin Date   End Date  Total CPI-Adjusted Cost (Millions of Dollars)  \
# 31 2017-09-19 2017-09-19                                       109800.0
# 49 2018-06-01 2018-06-01                                        28800.0
# 30 2017-09-06 2017-09-06                                        61000.0
# 29 2017-08-25 2017-08-25                                       152500.0
# 33 2017-06-01 2017-06-01                                        22146.2
# 46 2018-09-13 2018-09-13                                        28800.0
# 12 2016-10-08 2016-10-08                                        12500.0
# 47 2018-10-10 2018-10-10                                        29720.3
# 84 2020-08-01 2020-08-01                                        19082.0
# 85 2020-06-01 2020-06-01                                         5214.2
#
#     Deaths
# 31    2981
# 49     106
# 30      97
# 29      89
# 33      54
# 46      53
# 12      49
# 47      49
# 84      46
# 85      45

# %%
#Look at the events with the highest amount of Total CPI-Adjusted Cost (Size)
Extreme_Weather_Events_US.sort_values(by = "Total CPI-Adjusted Cost (Millions of Dollars)", ascending = False).head(10)
# Out:
#                                                  Name          Disaster  \
# 29                     Hurricane Harvey (August 2017)  Tropical Cyclone
# 31                   Hurricane Maria (September 2017)  Tropical Cyclone
# 30                    Hurricane Irma (September 2017)  Tropical Cyclone
# 47                   Hurricane Michael (October 2018)  Tropical Cyclone
# 46                Hurricane Florence (September 2018)  Tropical Cyclone
# 49  Western Wildfires, California Firestorm (Summe...          Wildfire
# 79                      Hurricane Laura (August 2020)  Tropical Cyclone
# 33  Western Wildfires, California Firestorm (Summe...          Wildfire
# 84  Western Wildfires - California, Oregon, Washin...          Wildfire
# 52  Missouri River and North Central Flooding (Mar...          Flooding
#
#    Begin Date   End Date  Total CPI-Adjusted Cost (Millions of Dollars)  \
# 29 2017-08-25 2017-08-25                                       152500.0
# 31 2017-09-19 2017-09-19                                       109800.0
# 30 2017-09-06 2017-09-06                                        61000.0
# 47 2018-10-10 2018-10-10                                        29720.3
# 46 2018-09-13 2018-09-13                                        28800.0
# 49 2018-06-01 2018-06-01                                        28800.0
# 79 2020-08-27 2020-08-27                                        26929.4
# 33 2017-06-01 2017-06-01                                        22146.2
# 84 2020-08-01 2020-08-01                                        19082.0
# 52 2019-03-14 2019-03-14                                        12872.4
#
#     Deaths
# 29      89
# 31    2981
# 30      97
# 47      49
# 46      53
# 49     106
# 79      42
# 33      54
# 84      46
# 52       3
