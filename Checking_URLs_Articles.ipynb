# %% [markdown]
# # 0. Packages & Functions

# %% [markdown]
# ## 0.1. Packages

# %%
import pandas as pd
import os

# %% [markdown]
# ## 0.2. Functions

# %% [markdown]
# # 1. Wall Street Journal

# %% [markdown]
# ## 1.1. URLs

# %%
URLs_WSJ_2016 = pd.read_parquet("Wall_Street_Journal_2016_URLS(1)")
URLs_WSJ_2017 = pd.read_parquet("Wall_Street_Journal_2017_URLS (2)")
URLs_WSJ_2018 = pd.read_parquet("Wall_Street_Journal_2018_URLS")
URLs_WSJ_2019 = pd.read_parquet("Wall_Street_Journal_2019_URLS")
URLs_WSJ_2020 = pd.read_parquet("Wall_Street_Journal_2020_URLS")

URLs_WSJ = pd.concat([URLs_WSJ_2016, URLs_WSJ_2017, URLs_WSJ_2018, URLs_WSJ_2019, URLs_WSJ_2020]).reset_index(drop = True)

# %%
URLs_WSJ
# Out:
#               Date           News Paper  \
# 0       01/01/2016  Wall_Street_Journal
# 1       01/01/2016  Wall_Street_Journal
# 2       01/01/2016  Wall_Street_Journal
# 3       01/01/2016  Wall_Street_Journal
# 4       01/01/2016  Wall_Street_Journal
# ...            ...                  ...
# 254877  31/12/2020  Wall_Street_Journal
# 254878  31/12/2020  Wall_Street_Journal
# 254879  31/12/2020  Wall_Street_Journal
# 254880  31/12/2020  Wall_Street_Journal
# 254881  31/12/2020  Wall_Street_Journal
#
#                                                      Link
# 0       http://www.wsj.com/articles/5-fashion-resoluti...
# 1       http://www.wsj.com/articles/suspect-in-new-yea...
# 2       http://www.wsj.com/articles/defenders-of-confe...
# 3       http://www.wsj.com/articles/saudi-women-seek-m...
# 4       http://www.wsj.com/articles/saudi-beheadings-a...
# ...                                                   ...
# 254877  https://www.wsj.com/articles/navalny-faces-fra...
# 254878  https://www.wsj.com/articles/chinese-markets-s...
# 254879  https://www.wsj.com/articles/astrazeneca-and-o...
# 254880  https://www.wsj.com/articles/covid-19-vaccine-...
# 254881  https://www.wsj.com/articles/pepper-and-salt-1...
#
# [254882 rows x 3 columns]

# %%
#Remove the duplicate rows and the URLs with an error message in

#duplicates
URLs_WSJ = URLs_WSJ.drop_duplicates().reset_index(drop = True)

#error
mask_WSJ_URLs_error = ~ URLs_WSJ['Link'].str.contains('mod=error_page')
URLs_WSJ = URLs_WSJ[mask_WSJ_URLs_error].reset_index(drop = True)

# %%
URLs_WSJ
# Out:
#               Date           News Paper  \
# 0       01/01/2016  Wall_Street_Journal
# 1       01/01/2016  Wall_Street_Journal
# 2       01/01/2016  Wall_Street_Journal
# 3       01/01/2016  Wall_Street_Journal
# 4       01/01/2016  Wall_Street_Journal
# ...            ...                  ...
# 254576  31/12/2020  Wall_Street_Journal
# 254577  31/12/2020  Wall_Street_Journal
# 254578  31/12/2020  Wall_Street_Journal
# 254579  31/12/2020  Wall_Street_Journal
# 254580  31/12/2020  Wall_Street_Journal
#
#                                                      Link
# 0       http://www.wsj.com/articles/5-fashion-resoluti...
# 1       http://www.wsj.com/articles/suspect-in-new-yea...
# 2       http://www.wsj.com/articles/defenders-of-confe...
# 3       http://www.wsj.com/articles/saudi-women-seek-m...
# 4       http://www.wsj.com/articles/saudi-beheadings-a...
# ...                                                   ...
# 254576  https://www.wsj.com/articles/navalny-faces-fra...
# 254577  https://www.wsj.com/articles/chinese-markets-s...
# 254578  https://www.wsj.com/articles/astrazeneca-and-o...
# 254579  https://www.wsj.com/articles/covid-19-vaccine-...
# 254580  https://www.wsj.com/articles/pepper-and-salt-1...
#
# [254581 rows x 3 columns]

# %%
#Collect URLs per year
URLs_WSJ["Date"] = pd.to_datetime(URLs_WSJ['Date'], format='%d/%m/%Y')
URLs_WSJ["Year"] = URLs_WSJ['Date'].dt.year

#Unique URLs -> unique combination of date and URL
WSJ_year_URLs_1 = URLs_WSJ.groupby(["News Paper","Year", "Date"])["Link"].nunique().reset_index(name='Unique_URLs_Count').groupby(["News Paper", "Year"]).sum("Unique_URLs_Count").reset_index()

#Unique URLs -> one URL on two different dates counts as one URL
WSJ_year_URLs_2 = URLs_WSJ.groupby(["News Paper","Year"])["Link"].nunique().reset_index(name='Unique_URLs_Count')

# %%
#Check WSJ_year_URLs_1
WSJ_year_URLs_1
# Out:
#             News Paper  Year  Unique_URLs_Count
# 0  Wall_Street_Journal  2016              74024
# 1  Wall_Street_Journal  2017              59731
# 2  Wall_Street_Journal  2018              48922
# 3  Wall_Street_Journal  2019              36290
# 4  Wall_Street_Journal  2020              35614

# %%
WSJ_year_URLs_1["Unique_URLs_Count"].sum()
# Out:
# 254581

# %%
WSJ_year_URLs_1.to_csv('C:/Users/Boedt/OneDrive/Bureaublad/R Thesis/WSJ_year_URLs_1', index = False)

# %%
#Check WSJ_year_URLs_2
WSJ_year_URLs_2
# Out:
#             News Paper  Year  Unique_URLs_Count
# 0  Wall_Street_Journal  2016              74023
# 1  Wall_Street_Journal  2017              59728
# 2  Wall_Street_Journal  2018              48917
# 3  Wall_Street_Journal  2019              36283
# 4  Wall_Street_Journal  2020              35613

# %% [markdown]
# ## 1.2. Articles

# %%
# Set the directory path
directory = "C:/Users/Boedt/OneDrive/Bureaublad/Scraped_Articles/Wall Street Journal"

# Get a list of filenames in the directory
filenames = os.listdir(directory)

# Loop through the filenames and read each Parquet file into a DataFrame
dfs = []
for filename in filenames:
    filepath = os.path.join(directory, filename)
    df = pd.read_parquet(filepath)
    dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
Articles_WSJ = pd.concat(dfs, ignore_index=True)

Articles_WSJ = Articles_WSJ.drop("index", axis = 1)

# %%
Articles_WSJ
# Out:
#                                                     Title  \
# 0                          5 Fashion Resolutions for 2016
# 1       Suspect in New Year’s Eve Terror Plot Is Panha...
# 2       Defenders of Confederate Symbols Mount a Count...
# 3                         Saudi Women Seek More Good Jobs
# 4       Saudi Beheadings at Highest Level in 20 Years,...
# ...                                                   ...
# 264704                              Smoother by the Dozen
# 264705       Everybody Wants Credit for the Covid Vaccine
# 264706                                 A Place in the Sun
# 264707  Shift Gears, Accelerate: CIOs Reordered IT Pri...
# 264708  An Adirondack-Style Retreat on Lake Coeur d’Alene
#
#                                                      Text  \
# 0        NEW YEAR’S RESOLUTIONS?I don’t need no stinki...
# 1        ROCHESTER, N.Y.—An ex-convict arrested in a p...
# 2        ATLANTA—Not since at least the civil-rights m...
# 3        RIYADH—Women in Saudi Arabia still aren’t all...
# 4        DUBAI, United Arab Emirates—Saudi Arabia carr...
# ...                                                   ...
# 264704                                          NO ACCESS
# 264705   Graham T. Allison correctly highlights the im...
# 264706                                          NO ACCESS
# 264707   Remote work and the acceleration of certain d...
# 264708                                          NO ACCESS
#
#                                                      Link        Date  \
# 0       http://www.wsj.com/articles/5-fashion-resoluti...  01/01/2016
# 1       http://www.wsj.com/articles/suspect-in-new-yea...  01/01/2016
# 2       http://www.wsj.com/articles/defenders-of-confe...  01/01/2016
# 3       http://www.wsj.com/articles/saudi-women-seek-m...  01/01/2016
# 4       http://www.wsj.com/articles/saudi-beheadings-a...  01/01/2016
# ...                                                   ...         ...
# 264704  https://www.wsj.com/articles/smoother-by-the-d...  29/12/2020
# 264705  https://www.wsj.com/articles/everybody-wants-c...  30/12/2020
# 264706  https://www.wsj.com/articles/a-place-in-the-su...  30/12/2020
# 264707  https://www.wsj.com/articles/shift-gears-accel...  30/12/2020
# 264708  https://www.wsj.com/articles/an-adirondack-sty...  31/12/2020
#
#                  News Paper
# 0       Wall_Street_Journal
# 1       Wall_Street_Journal
# 2       Wall_Street_Journal
# 3       Wall_Street_Journal
# 4       Wall_Street_Journal
# ...                     ...
# 264704  Wall_Street_Journal
# 264705  Wall_Street_Journal
# 264706  Wall_Street_Journal
# 264707  Wall_Street_Journal
# 264708  Wall_Street_Journal
#
# [264709 rows x 5 columns]

# %%
#Drop all duplicates and URLs with error message (we only found out about the error after scraping the URLs)

#duplicates
Articles_WSJ = Articles_WSJ.drop_duplicates().reset_index(drop = True)

#error
mask_WSJ_Articles_error = ~ Articles_WSJ['Link'].str.contains('mod=error_page')
Articles_WSJ = Articles_WSJ[mask_WSJ_Articles_error].reset_index(drop = True)

# %%
Articles_WSJ
# Out:
#                                                     Title  \
# 0                          5 Fashion Resolutions for 2016
# 1       Suspect in New Year’s Eve Terror Plot Is Panha...
# 2       Defenders of Confederate Symbols Mount a Count...
# 3                         Saudi Women Seek More Good Jobs
# 4       Saudi Beheadings at Highest Level in 20 Years,...
# ...                                                   ...
# 239988  ‘Sylvie’s Love’ Review: Lush Movie Life Reimag...
# 239989                                  Pepper...and Salt
# 239990  China Tells Ant Group to Refocus on Its Paymen...
# 239991       Everybody Wants Credit for the Covid Vaccine
# 239992  Shift Gears, Accelerate: CIOs Reordered IT Pri...
#
#                                                      Text  \
# 0        NEW YEAR’S RESOLUTIONS?I don’t need no stinki...
# 1        ROCHESTER, N.Y.—An ex-convict arrested in a p...
# 2        ATLANTA—Not since at least the civil-rights m...
# 3        RIYADH—Women in Saudi Arabia still aren’t all...
# 4        DUBAI, United Arab Emirates—Saudi Arabia carr...
# ...                                                   ...
# 239988   Eugene Ashe’s “Sylvie’s Love,” streaming on A...
# 239989
# 239990   Chinese financial regulators moved to rein in...
# 239991   Graham T. Allison correctly highlights the im...
# 239992   Remote work and the acceleration of certain d...
#
#                                                      Link        Date  \
# 0       http://www.wsj.com/articles/5-fashion-resoluti...  01/01/2016
# 1       http://www.wsj.com/articles/suspect-in-new-yea...  01/01/2016
# 2       http://www.wsj.com/articles/defenders-of-confe...  01/01/2016
# 3       http://www.wsj.com/articles/saudi-women-seek-m...  01/01/2016
# 4       http://www.wsj.com/articles/saudi-beheadings-a...  01/01/2016
# ...                                                   ...         ...
# 239988  https://www.wsj.com/articles/eugene-ashes-sump...  23/12/2020
# 239989  https://www.wsj.com/articles/pepper-and-salt-1...  26/12/2020
# 239990  https://www.wsj.com/articles/china-tells-ant-t...  27/12/2020
# 239991  https://www.wsj.com/articles/everybody-wants-c...  30/12/2020
# 239992  https://www.wsj.com/articles/shift-gears-accel...  30/12/2020
#
#                  News Paper
# 0       Wall_Street_Journal
# 1       Wall_Street_Journal
# 2       Wall_Street_Journal
# 3       Wall_Street_Journal
# 4       Wall_Street_Journal
# ...                     ...
# 239988  Wall_Street_Journal
# 239989  Wall_Street_Journal
# 239990  Wall_Street_Journal
# 239991  Wall_Street_Journal
# 239992  Wall_Street_Journal
#
# [239993 rows x 5 columns]

# %%
#Scraped articles per year (based on URLs)
Articles_WSJ["Date"] = pd.to_datetime(Articles_WSJ['Date'], format='%d/%m/%Y')
Articles_WSJ["Year"] = Articles_WSJ['Date'].dt.year

#Unique URLs -> unique combination of date and URL
WSJ_year_Articles_1 = Articles_WSJ.groupby(["News Paper","Year", "Date"])["Link"].nunique().reset_index(name='Unique_URLs_Count').groupby(["News Paper", "Year"]).sum("Unique_URLs_Count").reset_index()

#Unique URLs -> one URL on two different dates counts as one URL
WSJ_year_Articles_2 = Articles_WSJ.groupby(["News Paper","Year"])["Link"].nunique().reset_index(name='Unique_URLs_Count')

# %%
#Check WSJ_year_Articles_1
WSJ_year_Articles_1
# Out:
#             News Paper  Year  Unique_URLs_Count
# 0  Wall_Street_Journal  2016              71819
# 1  Wall_Street_Journal  2017              49757
# 2  Wall_Street_Journal  2018              28891
# 3  Wall_Street_Journal  2019              36185
# 4  Wall_Street_Journal  2020              32595

# %%
#Check WSJ_year_Articles_2
WSJ_year_Articles_2
# Out:
#             News Paper  Year  Unique_URLs_Count
# 0  Wall_Street_Journal  2016              71819
# 1  Wall_Street_Journal  2017              49754
# 2  Wall_Street_Journal  2018              28891
# 3  Wall_Street_Journal  2019              36178
# 4  Wall_Street_Journal  2020              32594

# %%
test = Articles_WSJ[["Date", "Link"]].value_counts().reset_index()
test.columns = ["Date", "Link", "Count"]
link = test[test["Count"] > 1]

# %%
link
# Out:
#             Date                                               Link  Count
# 0     2016-06-03  http://www.wsj.com/articles/sumner-redstone-ha...      3
# 1     2016-06-07  http://www.wsj.com/articles/wells-fargo-hopes-...      3
# 2     2016-06-08  http://www.wsj.com/articles/boston-scientific-...      3
# 3     2016-06-07  http://www.wsj.com/articles/lendingclub-postpo...      3
# 4     2016-06-06  http://www.wsj.com/articles/eu-to-start-delica...      3
# ...          ...                                                ...    ...
# 20638 2016-03-16  http://www.wsj.com/articles/new-york-city-anno...      2
# 20639 2016-03-16  http://www.wsj.com/articles/go-slow-britain-u-...      2
# 20640 2016-03-25  http://www.wsj.com/articles/senior-islamic-sta...      2
# 20641 2016-03-15  https://www.wsj.com/articles/greek-winter-sala...      2
# 20642 2016-03-15  http://www.wsj.com/articles/in-a-collection-of...      2
#
# [20643 rows x 3 columns]

# %%
#Articles_WSJ = Articles_WSJ.drop(Articles_WSJ[Articles_WSJ[["Link", "Date"]].duplicated() == True].index)

# %% [markdown]
# ## 1.3. Unscraped Articles

# %%
#Select all the URLs that were scraped, but are not present in the article data set (unscraped)
WSJ_unscraped_articles = URLs_WSJ[~URLs_WSJ["Link"].isin(Articles_WSJ["Link"])].reset_index(drop = True)

# %%
WSJ_unscraped_articles
# Out:
#             Date           News Paper  \
# 0     2016-06-16  Wall_Street_Journal
# 1     2016-06-17  Wall_Street_Journal
# 2     2016-06-20  Wall_Street_Journal
# 3     2016-06-21  Wall_Street_Journal
# 4     2016-06-21  Wall_Street_Journal
# ...          ...                  ...
# 35328 2020-05-15  Wall_Street_Journal
# 35329 2020-05-29  Wall_Street_Journal
# 35330 2020-06-01  Wall_Street_Journal
# 35331 2020-06-03  Wall_Street_Journal
# 35332 2020-06-05  Wall_Street_Journal
#
#                                                     Link  Year
# 0      http://www.wsj.com/articles/phil-mickelson-and...  2016
# 1      http://www.wsj.com/articles/dont-judge-lawsuit...  2016
# 2      http://www.wsj.com/articles/notable-quotable-v...  2016
# 3      http://www.wsj.com/articles/china-premier-vows...  2016
# 4      http://www.wsj.com/articles/chinas-one-way-dea...  2016
# ...                                                  ...   ...
# 35328  https://www.wsj.com/articles/coronavirus-pande...  2020
# 35329  https://www.wsj.com/articles/weve-hardly-gotte...  2020
# 35330  https://www.wsj.com/articles/pep-talk-for-poli...  2020
# 35331  https://www.wsj.com/articles/he-knew-george-fl...  2020
# 35332  https://www.wsj.com/articles/insecure-yvonne-o...  2020
#
# [35333 rows x 4 columns]

# %%
#Check the distribution per year
WSJ_unscraped_articles.groupby(["News Paper","Year", "Date"])["Link"].nunique().reset_index(name='Unique_URLs_Count').groupby(["News Paper", "Year"]).sum("Unique_URLs_Count").reset_index()
 
# -> November and December 2017 are missing and January untill April 2018 are missing. This explains the high numbers in those 
    #years
# Out:
#             News Paper  Year  Unique_URLs_Count
# 0  Wall_Street_Journal  2016               2204
# 1  Wall_Street_Journal  2017               9974
# 2  Wall_Street_Journal  2018              20031
# 3  Wall_Street_Journal  2019                105
# 4  Wall_Street_Journal  2020               3019

# %%
#Store the unscraped URLs so they can be rescraped! 
#WSJ_unscraped_articles.to_parquet("WSJ_missed_URLs")

# %% [markdown]
# ## 1.4. Useful Articles

# %%
#First store the Articles_WSJ in a new dataframe, this way we can keep the two separate.
Articles_WSJ_Clean = Articles_WSJ

# %%
Articles_WSJ_Clean
# Out:
#                                                     Title  \
# 0                          5 Fashion Resolutions for 2016
# 1       Suspect in New Year’s Eve Terror Plot Is Panha...
# 2       Defenders of Confederate Symbols Mount a Count...
# 3                         Saudi Women Seek More Good Jobs
# 4       Saudi Beheadings at Highest Level in 20 Years,...
# ...                                                   ...
# 239988  ‘Sylvie’s Love’ Review: Lush Movie Life Reimag...
# 239989                                  Pepper...and Salt
# 239990  China Tells Ant Group to Refocus on Its Paymen...
# 239991       Everybody Wants Credit for the Covid Vaccine
# 239992  Shift Gears, Accelerate: CIOs Reordered IT Pri...
#
#                                                      Text  \
# 0        NEW YEAR’S RESOLUTIONS?I don’t need no stinki...
# 1        ROCHESTER, N.Y.—An ex-convict arrested in a p...
# 2        ATLANTA—Not since at least the civil-rights m...
# 3        RIYADH—Women in Saudi Arabia still aren’t all...
# 4        DUBAI, United Arab Emirates—Saudi Arabia carr...
# ...                                                   ...
# 239988   Eugene Ashe’s “Sylvie’s Love,” streaming on A...
# 239989
# 239990   Chinese financial regulators moved to rein in...
# 239991   Graham T. Allison correctly highlights the im...
# 239992   Remote work and the acceleration of certain d...
#
#                                                      Link       Date  \
# 0       http://www.wsj.com/articles/5-fashion-resoluti... 2016-01-01
# 1       http://www.wsj.com/articles/suspect-in-new-yea... 2016-01-01
# 2       http://www.wsj.com/articles/defenders-of-confe... 2016-01-01
# 3       http://www.wsj.com/articles/saudi-women-seek-m... 2016-01-01
# 4       http://www.wsj.com/articles/saudi-beheadings-a... 2016-01-01
# ...                                                   ...        ...
# 239988  https://www.wsj.com/articles/eugene-ashes-sump... 2020-12-23
# 239989  https://www.wsj.com/articles/pepper-and-salt-1... 2020-12-26
# 239990  https://www.wsj.com/articles/china-tells-ant-t... 2020-12-27
# 239991  https://www.wsj.com/articles/everybody-wants-c... 2020-12-30
# 239992  https://www.wsj.com/articles/shift-gears-accel... 2020-12-30
#
#                  News Paper  Year
# 0       Wall_Street_Journal  2016
# 1       Wall_Street_Journal  2016
# 2       Wall_Street_Journal  2016
# 3       Wall_Street_Journal  2016
# 4       Wall_Street_Journal  2016
# ...                     ...   ...
# 239988  Wall_Street_Journal  2020
# 239989  Wall_Street_Journal  2020
# 239990  Wall_Street_Journal  2020
# 239991  Wall_Street_Journal  2020
# 239992  Wall_Street_Journal  2020
#
# [239993 rows x 6 columns]

# %%
#First we remove the articles we don't have access to, this is because they belong to the WSJ Pro subscription which we don't have.
#This is typically about VC and PE, so the added value seemed limited to us.
total_no_access = Articles_WSJ_Clean[Articles_WSJ_Clean["Text"] == "NO ACCESS"]["Text"].count()
total_unique_no_access = Articles_WSJ_Clean[Articles_WSJ_Clean["Text"] == "NO ACCESS"].groupby(["Date", "Link"])["Link"].count().reset_index(drop = True).sum()
print("Total NO ACCESS rows:", total_no_access, "and total unique ones:", total_unique_no_access)


remove_NO_ACCESS = ~ Articles_WSJ_Clean["Text"].str.contains("NO ACCESS")
Articles_WSJ_Clean = Articles_WSJ_Clean[remove_NO_ACCESS].reset_index(drop = True)
# Out:
# Total NO ACCESS rows: 34985 and total unique ones: 34985

# %%
Articles_WSJ_Clean[Articles_WSJ_Clean["Text"] == "NO ACCESS"]
# Out:
# Empty DataFrame
# Columns: [Title, Text, Link, Date, News Paper, Year]
# Index: []

# %%
Articles_WSJ_Clean
# Out:
#                                                     Title  \
# 0                          5 Fashion Resolutions for 2016
# 1       Suspect in New Year’s Eve Terror Plot Is Panha...
# 2       Defenders of Confederate Symbols Mount a Count...
# 3                         Saudi Women Seek More Good Jobs
# 4       Saudi Beheadings at Highest Level in 20 Years,...
# ...                                                   ...
# 205001  ‘Sylvie’s Love’ Review: Lush Movie Life Reimag...
# 205002                                  Pepper...and Salt
# 205003  China Tells Ant Group to Refocus on Its Paymen...
# 205004       Everybody Wants Credit for the Covid Vaccine
# 205005  Shift Gears, Accelerate: CIOs Reordered IT Pri...
#
#                                                      Text  \
# 0        NEW YEAR’S RESOLUTIONS?I don’t need no stinki...
# 1        ROCHESTER, N.Y.—An ex-convict arrested in a p...
# 2        ATLANTA—Not since at least the civil-rights m...
# 3        RIYADH—Women in Saudi Arabia still aren’t all...
# 4        DUBAI, United Arab Emirates—Saudi Arabia carr...
# ...                                                   ...
# 205001   Eugene Ashe’s “Sylvie’s Love,” streaming on A...
# 205002
# 205003   Chinese financial regulators moved to rein in...
# 205004   Graham T. Allison correctly highlights the im...
# 205005   Remote work and the acceleration of certain d...
#
#                                                      Link       Date  \
# 0       http://www.wsj.com/articles/5-fashion-resoluti... 2016-01-01
# 1       http://www.wsj.com/articles/suspect-in-new-yea... 2016-01-01
# 2       http://www.wsj.com/articles/defenders-of-confe... 2016-01-01
# 3       http://www.wsj.com/articles/saudi-women-seek-m... 2016-01-01
# 4       http://www.wsj.com/articles/saudi-beheadings-a... 2016-01-01
# ...                                                   ...        ...
# 205001  https://www.wsj.com/articles/eugene-ashes-sump... 2020-12-23
# 205002  https://www.wsj.com/articles/pepper-and-salt-1... 2020-12-26
# 205003  https://www.wsj.com/articles/china-tells-ant-t... 2020-12-27
# 205004  https://www.wsj.com/articles/everybody-wants-c... 2020-12-30
# 205005  https://www.wsj.com/articles/shift-gears-accel... 2020-12-30
#
#                  News Paper  Year
# 0       Wall_Street_Journal  2016
# 1       Wall_Street_Journal  2016
# 2       Wall_Street_Journal  2016
# 3       Wall_Street_Journal  2016
# 4       Wall_Street_Journal  2016
# ...                     ...   ...
# 205001  Wall_Street_Journal  2020
# 205002  Wall_Street_Journal  2020
# 205003  Wall_Street_Journal  2020
# 205004  Wall_Street_Journal  2020
# 205005  Wall_Street_Journal  2020
#
# [205006 rows x 6 columns]

# %%
#Do we remove the articles that contained pictures or cartoons -> we could assume the distribution of climate change is 
#equal in these articles, but we are not able to detect wether it is climate change or not. So we would have to remove them? 
#Also, this is about a neglectable portion of the articles, so not sorry wether this could potentialy effect the results


#we use an intermediate step, text cleaning of the articles happens after we removed the invalid ones
remove_blank_text_df = Articles_WSJ_Clean 
remove_blank_text_df["Text"] = remove_blank_text_df['Text'].str.strip(" ")
Articles_WSJ_Clean = Articles_WSJ_Clean.drop(remove_blank_text_df[remove_blank_text_df["Text"] == ""].index)

Articles_WSJ_Clean
# Out:
#                                                     Title  \
# 0                          5 Fashion Resolutions for 2016
# 1       Suspect in New Year’s Eve Terror Plot Is Panha...
# 2       Defenders of Confederate Symbols Mount a Count...
# 3                         Saudi Women Seek More Good Jobs
# 4       Saudi Beheadings at Highest Level in 20 Years,...
# ...                                                   ...
# 205000  Goldman Unit Makes New Push Into Real Estate W...
# 205001  ‘Sylvie’s Love’ Review: Lush Movie Life Reimag...
# 205003  China Tells Ant Group to Refocus on Its Paymen...
# 205004       Everybody Wants Credit for the Covid Vaccine
# 205005  Shift Gears, Accelerate: CIOs Reordered IT Pri...
#
#                                                      Text  \
# 0       NEW YEAR’S RESOLUTIONS?I don’t need no stinkin...
# 1       ROCHESTER, N.Y.—An ex-convict arrested in a pl...
# 2       ATLANTA—Not since at least the civil-rights mo...
# 3       RIYADH—Women in Saudi Arabia still aren’t allo...
# 4       DUBAI, United Arab Emirates—Saudi Arabia carri...
# ...                                                   ...
# 205000  A Goldman Sachs Group Inc. unit that buys stak...
# 205001  Eugene Ashe’s “Sylvie’s Love,” streaming on Am...
# 205003  Chinese financial regulators moved to rein in ...
# 205004  Graham T. Allison correctly highlights the imp...
# 205005  Remote work and the acceleration of certain di...
#
#                                                      Link       Date  \
# 0       http://www.wsj.com/articles/5-fashion-resoluti... 2016-01-01
# 1       http://www.wsj.com/articles/suspect-in-new-yea... 2016-01-01
# 2       http://www.wsj.com/articles/defenders-of-confe... 2016-01-01
# 3       http://www.wsj.com/articles/saudi-women-seek-m... 2016-01-01
# 4       http://www.wsj.com/articles/saudi-beheadings-a... 2016-01-01
# ...                                                   ...        ...
# 205000  https://www.wsj.com/articles/goldman-unit-make... 2020-12-22
# 205001  https://www.wsj.com/articles/eugene-ashes-sump... 2020-12-23
# 205003  https://www.wsj.com/articles/china-tells-ant-t... 2020-12-27
# 205004  https://www.wsj.com/articles/everybody-wants-c... 2020-12-30
# 205005  https://www.wsj.com/articles/shift-gears-accel... 2020-12-30
#
#                  News Paper  Year
# 0       Wall_Street_Journal  2016
# 1       Wall_Street_Journal  2016
# 2       Wall_Street_Journal  2016
# 3       Wall_Street_Journal  2016
# 4       Wall_Street_Journal  2016
# ...                     ...   ...
# 205000  Wall_Street_Journal  2020
# 205001  Wall_Street_Journal  2020
# 205003  Wall_Street_Journal  2020
# 205004  Wall_Street_Journal  2020
# 205005  Wall_Street_Journal  2020
#
# [200201 rows x 6 columns]

# %%
#Some articles did not contain text, but only a pdf that could be downloaded. We remove these for same the reasoning why we 
#removed pictures and cartoons

Articles_WSJ_Clean = Articles_WSJ_Clean[Articles_WSJ_Clean["Text"] != "Download PDF"].reset_index(drop = True)
Articles_WSJ_Clean = Articles_WSJ_Clean[Articles_WSJ_Clean["Text"] != "See Solution Download PDF"].reset_index(drop = True)
Articles_WSJ_Clean = Articles_WSJ_Clean[Articles_WSJ_Clean["Text"] != "Download PDF See Solution"].reset_index(drop = True)

# %%
Articles_WSJ_Clean
# Out:
#                                                     Title  \
# 0                          5 Fashion Resolutions for 2016
# 1       Suspect in New Year’s Eve Terror Plot Is Panha...
# 2       Defenders of Confederate Symbols Mount a Count...
# 3                         Saudi Women Seek More Good Jobs
# 4       Saudi Beheadings at Highest Level in 20 Years,...
# ...                                                   ...
# 200134  Goldman Unit Makes New Push Into Real Estate W...
# 200135  ‘Sylvie’s Love’ Review: Lush Movie Life Reimag...
# 200136  China Tells Ant Group to Refocus on Its Paymen...
# 200137       Everybody Wants Credit for the Covid Vaccine
# 200138  Shift Gears, Accelerate: CIOs Reordered IT Pri...
#
#                                                      Text  \
# 0       NEW YEAR’S RESOLUTIONS?I don’t need no stinkin...
# 1       ROCHESTER, N.Y.—An ex-convict arrested in a pl...
# 2       ATLANTA—Not since at least the civil-rights mo...
# 3       RIYADH—Women in Saudi Arabia still aren’t allo...
# 4       DUBAI, United Arab Emirates—Saudi Arabia carri...
# ...                                                   ...
# 200134  A Goldman Sachs Group Inc. unit that buys stak...
# 200135  Eugene Ashe’s “Sylvie’s Love,” streaming on Am...
# 200136  Chinese financial regulators moved to rein in ...
# 200137  Graham T. Allison correctly highlights the imp...
# 200138  Remote work and the acceleration of certain di...
#
#                                                      Link       Date  \
# 0       http://www.wsj.com/articles/5-fashion-resoluti... 2016-01-01
# 1       http://www.wsj.com/articles/suspect-in-new-yea... 2016-01-01
# 2       http://www.wsj.com/articles/defenders-of-confe... 2016-01-01
# 3       http://www.wsj.com/articles/saudi-women-seek-m... 2016-01-01
# 4       http://www.wsj.com/articles/saudi-beheadings-a... 2016-01-01
# ...                                                   ...        ...
# 200134  https://www.wsj.com/articles/goldman-unit-make... 2020-12-22
# 200135  https://www.wsj.com/articles/eugene-ashes-sump... 2020-12-23
# 200136  https://www.wsj.com/articles/china-tells-ant-t... 2020-12-27
# 200137  https://www.wsj.com/articles/everybody-wants-c... 2020-12-30
# 200138  https://www.wsj.com/articles/shift-gears-accel... 2020-12-30
#
#                  News Paper  Year
# 0       Wall_Street_Journal  2016
# 1       Wall_Street_Journal  2016
# 2       Wall_Street_Journal  2016
# 3       Wall_Street_Journal  2016
# 4       Wall_Street_Journal  2016
# ...                     ...   ...
# 200134  Wall_Street_Journal  2020
# 200135  Wall_Street_Journal  2020
# 200136  Wall_Street_Journal  2020
# 200137  Wall_Street_Journal  2020
# 200138  Wall_Street_Journal  2020
#
# [200139 rows x 6 columns]

# %%
#Finally, after taking a look into other articles, we noticed that some articles were also unsuccesfully scraped. -> certain
#articles only contained the phrase "write to" which is always mentioned at the end of the article. This could be due to errors
#in the HTML or code. subset these and check! Is only around 3k articles. 

Articles_WSJ_Clean = Articles_WSJ_Clean[~Articles_WSJ_Clean["Text"].str.startswith('Write to')].reset_index(drop = True)

Articles_WSJ_Clean
# Out:
#                                                     Title  \
# 0                          5 Fashion Resolutions for 2016
# 1       Suspect in New Year’s Eve Terror Plot Is Panha...
# 2       Defenders of Confederate Symbols Mount a Count...
# 3                         Saudi Women Seek More Good Jobs
# 4       Saudi Beheadings at Highest Level in 20 Years,...
# ...                                                   ...
# 197009  Goldman Unit Makes New Push Into Real Estate W...
# 197010  ‘Sylvie’s Love’ Review: Lush Movie Life Reimag...
# 197011  China Tells Ant Group to Refocus on Its Paymen...
# 197012       Everybody Wants Credit for the Covid Vaccine
# 197013  Shift Gears, Accelerate: CIOs Reordered IT Pri...
#
#                                                      Text  \
# 0       NEW YEAR’S RESOLUTIONS?I don’t need no stinkin...
# 1       ROCHESTER, N.Y.—An ex-convict arrested in a pl...
# 2       ATLANTA—Not since at least the civil-rights mo...
# 3       RIYADH—Women in Saudi Arabia still aren’t allo...
# 4       DUBAI, United Arab Emirates—Saudi Arabia carri...
# ...                                                   ...
# 197009  A Goldman Sachs Group Inc. unit that buys stak...
# 197010  Eugene Ashe’s “Sylvie’s Love,” streaming on Am...
# 197011  Chinese financial regulators moved to rein in ...
# 197012  Graham T. Allison correctly highlights the imp...
# 197013  Remote work and the acceleration of certain di...
#
#                                                      Link       Date  \
# 0       http://www.wsj.com/articles/5-fashion-resoluti... 2016-01-01
# 1       http://www.wsj.com/articles/suspect-in-new-yea... 2016-01-01
# 2       http://www.wsj.com/articles/defenders-of-confe... 2016-01-01
# 3       http://www.wsj.com/articles/saudi-women-seek-m... 2016-01-01
# 4       http://www.wsj.com/articles/saudi-beheadings-a... 2016-01-01
# ...                                                   ...        ...
# 197009  https://www.wsj.com/articles/goldman-unit-make... 2020-12-22
# 197010  https://www.wsj.com/articles/eugene-ashes-sump... 2020-12-23
# 197011  https://www.wsj.com/articles/china-tells-ant-t... 2020-12-27
# 197012  https://www.wsj.com/articles/everybody-wants-c... 2020-12-30
# 197013  https://www.wsj.com/articles/shift-gears-accel... 2020-12-30
#
#                  News Paper  Year
# 0       Wall_Street_Journal  2016
# 1       Wall_Street_Journal  2016
# 2       Wall_Street_Journal  2016
# 3       Wall_Street_Journal  2016
# 4       Wall_Street_Journal  2016
# ...                     ...   ...
# 197009  Wall_Street_Journal  2020
# 197010  Wall_Street_Journal  2020
# 197011  Wall_Street_Journal  2020
# 197012  Wall_Street_Journal  2020
# 197013  Wall_Street_Journal  2020
#
# [197014 rows x 6 columns]

# %%
#Useful URLs per year
Articles_WSJ_Clean["Date"] = pd.to_datetime(Articles_WSJ_Clean['Date'], format='%d/%m/%Y')
Articles_WSJ_Clean["Year"] = Articles_WSJ_Clean['Date'].dt.year

#Unique URLs -> unique combination of date and URL
WSJ_year_useful_Articles_1 = Articles_WSJ_Clean.groupby(["News Paper","Year", "Date"])["Link"].nunique().reset_index(name='Unique_URLs_Count').groupby(["News Paper", "Year"]).sum("Unique_URLs_Count").reset_index()

#Unique URLs -> one URL on two different dates counts as one URL
WSJ_year_useful_Articles_2 = Articles_WSJ_Clean.groupby(["News Paper","Year"])["Link"].nunique().reset_index(name='Unique_URLs_Count')

# %%
#Check WSJ_year_useful_Articles_1
WSJ_year_useful_Articles_1
# Out:
#             News Paper  Year  Unique_URLs_Count
# 0  Wall_Street_Journal  2016              61253
# 1  Wall_Street_Journal  2017              30824
# 2  Wall_Street_Journal  2018              22162
# 3  Wall_Street_Journal  2019              35122
# 4  Wall_Street_Journal  2020              31808

# %%
#Total usefull articles
WSJ_year_useful_Articles_1["Unique_URLs_Count"].sum()
# Out:
# 181169

# %%
#WSJ_year_useful_Articles_1.to_csv("C:/Users/Boedt/OneDrive/Bureaublad/R Thesis/WSJ_year_useful_Articles_1", index = False)

# %%
#Compare to URLs we got in the beginning
Comparison_WSJ_1 = pd.merge(WSJ_year_URLs_1, WSJ_year_useful_Articles_1, on = ["News Paper", 'Year'])
Comparison_WSJ_1.columns = ["News Paper", "Year", "Unique_URLs_Count", "Useful_Unique_URLs_Count"]
Comparison_WSJ_1["Difference"] = Comparison_WSJ_1["Unique_URLs_Count"] - Comparison_WSJ_1["Useful_Unique_URLs_Count"]

# %%
Comparison_WSJ_1
# Out:
#             News Paper  Year  Unique_URLs_Count  Useful_Unique_URLs_Count  \
# 0  Wall_Street_Journal  2016              74024                     61253
# 1  Wall_Street_Journal  2017              59731                     30824
# 2  Wall_Street_Journal  2018              48922                     22162
# 3  Wall_Street_Journal  2019              36290                     35122
# 4  Wall_Street_Journal  2020              35614                     31808
#
#    Difference
# 0       12771
# 1       28907
# 2       26760
# 3        1168
# 4        3806

# %%
#Check WSJ_year_useful_Articles_2
WSJ_year_useful_Articles_2
# Out:
#             News Paper  Year  Unique_URLs_Count
# 0  Wall_Street_Journal  2016              61253
# 1  Wall_Street_Journal  2017              30824
# 2  Wall_Street_Journal  2018              22162
# 3  Wall_Street_Journal  2019              35117
# 4  Wall_Street_Journal  2020              31807

# %%
#Total useful articles 
WSJ_year_useful_Articles_2["Unique_URLs_Count"].sum()
# Out:
# 181163

# %%
#Compare to URLs we got in the beginning
Comparison_WSJ_2 = pd.merge(WSJ_year_URLs_2, WSJ_year_useful_Articles_2, on = ["News Paper", 'Year'])
Comparison_WSJ_2.columns = ["News Paper", "Year", "Unique_URLs_Count", "Useful_Unique_URLs_Count"]
Comparison_WSJ_2["Difference"] = Comparison_WSJ_2["Unique_URLs_Count"] - Comparison_WSJ_2["Useful_Unique_URLs_Count"]

# %%
Comparison_WSJ_2
# Out:
#             News Paper  Year  Unique_URLs_Count  Useful_Unique_URLs_Count  \
# 0  Wall_Street_Journal  2016              74023                     61253
# 1  Wall_Street_Journal  2017              59728                     30824
# 2  Wall_Street_Journal  2018              48917                     22162
# 3  Wall_Street_Journal  2019              36283                     35117
# 4  Wall_Street_Journal  2020              35613                     31807
#
#    Difference
# 0       12770
# 1       28904
# 2       26755
# 3        1166
# 4        3806

# %% [markdown]
# # 2. Washington Post

# %% [markdown]
# ## 2.1. URLs

# %%
URLs_WP_2016 = pd.read_parquet("Washington_Post_2016_URLS")
URLs_WP_2017 = pd.read_parquet("Washington_Post_2017_URLS")
URLs_WP_2018 = pd.read_parquet("Washington_Post_2018_URLS")
URLs_WP_2019 = pd.read_parquet("Washington_Post_2019_URLS")
URLs_WP_2020 = pd.read_parquet("Washington_Post_2020_URLS")

URLs_WP = pd.concat([URLs_WP_2016, URLs_WP_2017, URLs_WP_2018, URLs_WP_2019, URLs_WP_2020])

# %%
URLs_WP
# Out:
#              Date       News Paper  \
# 0      29/02/2016  Washington_Post
# 1      29/02/2016  Washington_Post
# 2      29/02/2016  Washington_Post
# 3      29/02/2016  Washington_Post
# 4      29/02/2016  Washington_Post
# ...           ...              ...
# 13748  31/12/2020  Washington_Post
# 13749  31/12/2020  Washington_Post
# 13750  31/12/2020  Washington_Post
# 13751  31/12/2020  Washington_Post
# 13752  31/12/2020  Washington_Post
#
#                                                     Link
# 0      https://www.washingtonpost.com/news/capitals-i...
# 1      https://www.washingtonpost.com/news/checkpoint...
# 2      https://www.washingtonpost.com/news/the-fix/wp...
# 3      https://www.washingtonpost.com/news/the-watch/...
# 4      https://www.washingtonpost.com/news/early-lead...
# ...                                                  ...
# 13748  https://www.washingtonpost.com/national/nation...
# 13749  https://www.washingtonpost.com/local/trump-jan...
# 13750  https://www.washingtonpost.com/politics/secret...
# 13751  https://www.washingtonpost.com/opinions/2021s-...
# 13752  https://www.washingtonpost.com/national-securi...
#
# [153178 rows x 3 columns]

# %%
#Remove the duplicates
URLs_WP = URLs_WP.drop_duplicates().reset_index(drop = True)

# %%
URLs_WP
# Out:
#               Date       News Paper  \
# 0       29/02/2016  Washington_Post
# 1       29/02/2016  Washington_Post
# 2       29/02/2016  Washington_Post
# 3       29/02/2016  Washington_Post
# 4       29/02/2016  Washington_Post
# ...            ...              ...
# 153173  31/12/2020  Washington_Post
# 153174  31/12/2020  Washington_Post
# 153175  31/12/2020  Washington_Post
# 153176  31/12/2020  Washington_Post
# 153177  31/12/2020  Washington_Post
#
#                                                      Link
# 0       https://www.washingtonpost.com/news/capitals-i...
# 1       https://www.washingtonpost.com/news/checkpoint...
# 2       https://www.washingtonpost.com/news/the-fix/wp...
# 3       https://www.washingtonpost.com/news/the-watch/...
# 4       https://www.washingtonpost.com/news/early-lead...
# ...                                                   ...
# 153173  https://www.washingtonpost.com/national/nation...
# 153174  https://www.washingtonpost.com/local/trump-jan...
# 153175  https://www.washingtonpost.com/politics/secret...
# 153176  https://www.washingtonpost.com/opinions/2021s-...
# 153177  https://www.washingtonpost.com/national-securi...
#
# [153178 rows x 3 columns]

# %%
#Collect URLs per year
URLs_WP["Date"] = pd.to_datetime(URLs_WP['Date'], format='%d/%m/%Y')
URLs_WP["Year"] = URLs_WP['Date'].dt.year

#Unique URLs -> unique combination of date and URL
WP_year_URLs_1 = URLs_WP.groupby(["News Paper","Year", "Date"])["Link"].nunique().reset_index(name='Unique_URLs_Count').groupby(["News Paper", "Year"]).sum("Unique_URLs_Count").reset_index()

#Unique URLs -> one URL on two different dates counts as one URL
WP_year_URLs_2 = URLs_WP.groupby(["News Paper","Year"])["Link"].nunique().reset_index(name='Unique_URLs_Count')

# %%
#Check WP_year_URLs_1
WP_year_URLs_1
# Out:
#         News Paper  Year  Unique_URLs_Count
# 0  Washington_Post  2016              49756
# 1  Washington_Post  2017              50442
# 2  Washington_Post  2018              28952
# 3  Washington_Post  2019              10275
# 4  Washington_Post  2020              13753

# %%
WP_year_URLs_1["Unique_URLs_Count"].sum()
# Out:
# 153178

# %%
#WP_year_URLs_1.to_csv("C:/Users/Boedt/OneDrive/Bureaublad/R Thesis/WP_year_URLs_1", index = False)

# %%
#Check WP_year_URLs_2
WP_year_URLs_2
# Out:
#         News Paper  Year  Unique_URLs_Count
# 0  Washington_Post  2016              49756
# 1  Washington_Post  2017              50442
# 2  Washington_Post  2018              28952
# 3  Washington_Post  2019              10275
# 4  Washington_Post  2020              13753

# %% [markdown]
# ## 2.2. Articles

# %%
# Set the directory path
directory = "C:/Users/Boedt/OneDrive/Bureaublad/Scraped_Articles/Washington Post"

# Get a list of filenames in the directory
filenames = os.listdir(directory)

# Loop through the filenames and read each Parquet file into a DataFrame
dfs = []
for filename in filenames:
    filepath = os.path.join(directory, filename)
    df = pd.read_parquet(filepath)
    dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
Articles_WP = pd.concat(dfs, ignore_index=True)
Articles_WP = Articles_WP.drop("Dat", axis = 1)

# %%
Articles_WP
# Out:
#                                                     Title  \
# 0       Clues to how a young man went from ‘classic te...
# 1       ‘Homelessly in Love’ tells stories of love ami...
# 2       Looking for a star for your winter garden? Try...
# 3       7 questions to ask yourself before taking on a...
# 4       Congress will return to a full slate of diffic...
# ...                                                   ...
# 175628  Shivering in line for a swab up the nose, but ...
# 175629  National Digest: Nashville woman warned police...
# 175630  Jan. 6 protests multiply as Trump continues to...
# 175631                      2021’s call to Reconstruction
# 175632  2020 saw an unprecedented spike in homicides f...
#
#                                                      Text        Date  \
# 0       Sean Andrew Duncan, 21, of Sterling, will be a...  01/01/2018
# 1       The documentary "Homelessly in Love" tells sto...  01/01/2018
# 2       Winterberry holly. (Adrian Higgins/TWP)\nComme...  01/01/2018
# 3       (bee32/Getty Images/iStockphoto)\nComment\n0\n...  01/01/2018
# 4       The GOP is starting 2018 with a lofty legislat...  01/01/2018
# ...                                                   ...         ...
# 175628  It was dusk on the third-to-last day of a terr...  31/12/2020
# 175629                                                     31/12/2020
# 175630  Protests planned in support of President Trump...  31/12/2020
# 175631  One of the singularly important intellectual d...  31/12/2020
# 175632  2020 has been a killer year in every way, incl...  31/12/2020
#
#              News Paper                                               Link
# 0       Washington_Post  https://www.washingtonpost.com/local/public-sa...
# 1       Washington_Post  https://www.washingtonpost.com/local/homelessl...
# 2       Washington_Post  https://www.washingtonpost.com/lifestyle/home/...
# 3       Washington_Post  https://www.washingtonpost.com/lifestyle/home/...
# 4       Washington_Post  https://www.washingtonpost.com/business/econom...
# ...                 ...                                                ...
# 175628  Washington_Post  https://www.washingtonpost.com/local/new-year-...
# 175629  Washington_Post  https://www.washingtonpost.com/national/nation...
# 175630  Washington_Post  https://www.washingtonpost.com/local/trump-jan...
# 175631  Washington_Post  https://www.washingtonpost.com/opinions/2021s-...
# 175632  Washington_Post  https://www.washingtonpost.com/national-securi...
#
# [175633 rows x 5 columns]

# %%
#Drop all duplicates
Articles_WP = Articles_WP.drop_duplicates().reset_index(drop = True)

# %%
#Scraped articles per year (based on URLs)
Articles_WP["Date"] = pd.to_datetime(Articles_WP['Date'], format='%d/%m/%Y')
Articles_WP["Year"] = Articles_WP['Date'].dt.year

#Unique URLs -> unique combination of date and URL
WP_year_Articles_1 = Articles_WP.groupby(["News Paper","Year", "Date"])["Link"].nunique().reset_index(name='Unique_URLs_Count').groupby(["News Paper", "Year"]).sum("Unique_URLs_Count").reset_index()

#Unique URLs -> one URL on two different dates counts as one URL
WP_year_Articles_2 = Articles_WP.groupby(["News Paper","Year"])["Link"].nunique().reset_index(name='Unique_URLs_Count')

# %%
#Check WP_year_Articles_1
WP_year_Articles_1
# Out:
#         News Paper  Year  Unique_URLs_Count
# 0  Washington_Post  2016              49664
# 1  Washington_Post  2017              49800
# 2  Washington_Post  2018              27888
# 3  Washington_Post  2019              10233
# 4  Washington_Post  2020              13697

# %%
#Check WP_year_Articles_2
WP_year_Articles_2
# Out:
#         News Paper  Year  Unique_URLs_Count
# 0  Washington_Post  2016              49664
# 1  Washington_Post  2017              49800
# 2  Washington_Post  2018              27888
# 3  Washington_Post  2019              10233
# 4  Washington_Post  2020              13697

# %% [markdown]
# ## 2.3. Unscraped Articles

# %%
#Select all the URLs that were scraped, but are not present in the article data set (unscraped)
WP_unscraped_articles = URLs_WP[~URLs_WP["Link"].isin(Articles_WP["Link"])].reset_index(drop = True)

# %%
WP_unscraped_articles
# Out:
#            Date       News Paper  \
# 0    2016-07-22  Washington_Post
# 1    2016-07-24  Washington_Post
# 2    2016-07-26  Washington_Post
# 3    2016-07-27  Washington_Post
# 4    2016-07-28  Washington_Post
# ...         ...              ...
# 1891 2020-12-05  Washington_Post
# 1892 2020-12-11  Washington_Post
# 1893 2020-12-17  Washington_Post
# 1894 2020-12-23  Washington_Post
# 1895 2020-12-31  Washington_Post
#
#                                                    Link  Year
# 0     https://www.washingtonpost.com/entertainment/t...  2016
# 1     https://www.washingtonpost.com/news/morning-mi...  2016
# 2     https://www.washingtonpost.com/politics/in-tig...  2016
# 3     https://www.washingtonpost.com/news/energy-env...  2016
# 4     https://www.washingtonpost.com/local/born-befo...  2016
# ...                                                 ...   ...
# 1891  https://www.washingtonpost.com/world/europe/ge...  2020
# 1892  https://www.washingtonpost.com/local/obituarie...  2020
# 1893  https://www.washingtonpost.com/lifestyle/advic...  2020
# 1894  https://www.washingtonpost.com/lifestyle/advic...  2020
# 1895  https://www.washingtonpost.com/politics/secret...  2020
#
# [1896 rows x 4 columns]

# %%
#Check the distribution per year
WP_unscraped_articles.groupby(["News Paper","Year", "Date"])["Link"].nunique().reset_index(name='Unique_URLs_Count').groupby(["News Paper", "Year"]).sum("Unique_URLs_Count").reset_index()
# Out:
#         News Paper  Year  Unique_URLs_Count
# 0  Washington_Post  2016                 92
# 1  Washington_Post  2017                642
# 2  Washington_Post  2018               1064
# 3  Washington_Post  2019                 42
# 4  Washington_Post  2020                 56

# %%
#Store the unscraped URLs so they can be rescraped! 
#WP_unscraped_articles.to_parquet("WP_missed_URLs")

# %% [markdown]
# ## 2.4. Useful Articles

# %%
Articles_WP_Clean = Articles_WP

# %%
Articles_WP_Clean
# Out:
#                                                     Title  \
# 0       Clues to how a young man went from ‘classic te...
# 1       ‘Homelessly in Love’ tells stories of love ami...
# 2       Looking for a star for your winter garden? Try...
# 3       7 questions to ask yourself before taking on a...
# 4       Congress will return to a full slate of diffic...
# ...                                                   ...
# 173312  Shivering in line for a swab up the nose, but ...
# 173313  National Digest: Nashville woman warned police...
# 173314  Jan. 6 protests multiply as Trump continues to...
# 173315                      2021’s call to Reconstruction
# 173316  2020 saw an unprecedented spike in homicides f...
#
#                                                      Text       Date  \
# 0       Sean Andrew Duncan, 21, of Sterling, will be a... 2018-01-01
# 1       The documentary "Homelessly in Love" tells sto... 2018-01-01
# 2       Winterberry holly. (Adrian Higgins/TWP)\nComme... 2018-01-01
# 3       (bee32/Getty Images/iStockphoto)\nComment\n0\n... 2018-01-01
# 4       The GOP is starting 2018 with a lofty legislat... 2018-01-01
# ...                                                   ...        ...
# 173312  It was dusk on the third-to-last day of a terr... 2020-12-31
# 173313                                                    2020-12-31
# 173314  Protests planned in support of President Trump... 2020-12-31
# 173315  One of the singularly important intellectual d... 2020-12-31
# 173316  2020 has been a killer year in every way, incl... 2020-12-31
#
#              News Paper                                               Link  \
# 0       Washington_Post  https://www.washingtonpost.com/local/public-sa...
# 1       Washington_Post  https://www.washingtonpost.com/local/homelessl...
# 2       Washington_Post  https://www.washingtonpost.com/lifestyle/home/...
# 3       Washington_Post  https://www.washingtonpost.com/lifestyle/home/...
# 4       Washington_Post  https://www.washingtonpost.com/business/econom...
# ...                 ...                                                ...
# 173312  Washington_Post  https://www.washingtonpost.com/local/new-year-...
# 173313  Washington_Post  https://www.washingtonpost.com/national/nation...
# 173314  Washington_Post  https://www.washingtonpost.com/local/trump-jan...
# 173315  Washington_Post  https://www.washingtonpost.com/opinions/2021s-...
# 173316  Washington_Post  https://www.washingtonpost.com/national-securi...
#
#         Year
# 0       2018
# 1       2018
# 2       2018
# 3       2018
# 4       2018
# ...      ...
# 173312  2020
# 173313  2020
# 173314  2020
# 173315  2020
# 173316  2020
#
# [173317 rows x 6 columns]

# %%
#Remove empty text
remove_blank_text_df = Articles_WP_Clean 
remove_blank_text_df["Text"] = remove_blank_text_df['Text'].str.strip(" ")
Articles_WP_Clean = Articles_WP_Clean.drop(remove_blank_text_df[remove_blank_text_df["Text"] == ""].index).reset_index(drop = True)

Articles_WP_Clean
# Out:
#                                                     Title  \
# 0       Clues to how a young man went from ‘classic te...
# 1       ‘Homelessly in Love’ tells stories of love ami...
# 2       Looking for a star for your winter garden? Try...
# 3       7 questions to ask yourself before taking on a...
# 4       Congress will return to a full slate of diffic...
# ...                                                   ...
# 139527  By the end of 2020, we were supposed to have m...
# 139528  Shivering in line for a swab up the nose, but ...
# 139529  Jan. 6 protests multiply as Trump continues to...
# 139530                      2021’s call to Reconstruction
# 139531  2020 saw an unprecedented spike in homicides f...
#
#                                                      Text       Date  \
# 0       Sean Andrew Duncan, 21, of Sterling, will be a... 2018-01-01
# 1       The documentary "Homelessly in Love" tells sto... 2018-01-01
# 2       Winterberry holly. (Adrian Higgins/TWP)\nComme... 2018-01-01
# 3       (bee32/Getty Images/iStockphoto)\nComment\n0\n... 2018-01-01
# 4       The GOP is starting 2018 with a lofty legislat... 2018-01-01
# ...                                                   ...        ...
# 139527  In an alternate-universe version of 2020 — and... 2020-12-31
# 139528  It was dusk on the third-to-last day of a terr... 2020-12-31
# 139529  Protests planned in support of President Trump... 2020-12-31
# 139530  One of the singularly important intellectual d... 2020-12-31
# 139531  2020 has been a killer year in every way, incl... 2020-12-31
#
#              News Paper                                               Link  \
# 0       Washington_Post  https://www.washingtonpost.com/local/public-sa...
# 1       Washington_Post  https://www.washingtonpost.com/local/homelessl...
# 2       Washington_Post  https://www.washingtonpost.com/lifestyle/home/...
# 3       Washington_Post  https://www.washingtonpost.com/lifestyle/home/...
# 4       Washington_Post  https://www.washingtonpost.com/business/econom...
# ...                 ...                                                ...
# 139527  Washington_Post  https://www.washingtonpost.com/entertainment/b...
# 139528  Washington_Post  https://www.washingtonpost.com/local/new-year-...
# 139529  Washington_Post  https://www.washingtonpost.com/local/trump-jan...
# 139530  Washington_Post  https://www.washingtonpost.com/opinions/2021s-...
# 139531  Washington_Post  https://www.washingtonpost.com/national-securi...
#
#         Year
# 0       2018
# 1       2018
# 2       2018
# 3       2018
# 4       2018
# ...      ...
# 139527  2020
# 139528  2020
# 139529  2020
# 139530  2020
# 139531  2020
#
# [139532 rows x 6 columns]

# %%
Articles_WP_Clean = Articles_WP_Clean[Articles_WP_Clean['Text'].apply(lambda x: len(x.split(" ")) != 1)].reset_index(drop = True)

# %%
Articles_WP_Clean
# Out:
#                                                     Title  \
# 0       Clues to how a young man went from ‘classic te...
# 1       ‘Homelessly in Love’ tells stories of love ami...
# 2       Looking for a star for your winter garden? Try...
# 3       7 questions to ask yourself before taking on a...
# 4       Congress will return to a full slate of diffic...
# ...                                                   ...
# 119967  By the end of 2020, we were supposed to have m...
# 119968  Shivering in line for a swab up the nose, but ...
# 119969  Jan. 6 protests multiply as Trump continues to...
# 119970                      2021’s call to Reconstruction
# 119971  2020 saw an unprecedented spike in homicides f...
#
#                                                      Text       Date  \
# 0       Sean Andrew Duncan, 21, of Sterling, will be a... 2018-01-01
# 1       The documentary "Homelessly in Love" tells sto... 2018-01-01
# 2       Winterberry holly. (Adrian Higgins/TWP)\nComme... 2018-01-01
# 3       (bee32/Getty Images/iStockphoto)\nComment\n0\n... 2018-01-01
# 4       The GOP is starting 2018 with a lofty legislat... 2018-01-01
# ...                                                   ...        ...
# 119967  In an alternate-universe version of 2020 — and... 2020-12-31
# 119968  It was dusk on the third-to-last day of a terr... 2020-12-31
# 119969  Protests planned in support of President Trump... 2020-12-31
# 119970  One of the singularly important intellectual d... 2020-12-31
# 119971  2020 has been a killer year in every way, incl... 2020-12-31
#
#              News Paper                                               Link  \
# 0       Washington_Post  https://www.washingtonpost.com/local/public-sa...
# 1       Washington_Post  https://www.washingtonpost.com/local/homelessl...
# 2       Washington_Post  https://www.washingtonpost.com/lifestyle/home/...
# 3       Washington_Post  https://www.washingtonpost.com/lifestyle/home/...
# 4       Washington_Post  https://www.washingtonpost.com/business/econom...
# ...                 ...                                                ...
# 119967  Washington_Post  https://www.washingtonpost.com/entertainment/b...
# 119968  Washington_Post  https://www.washingtonpost.com/local/new-year-...
# 119969  Washington_Post  https://www.washingtonpost.com/local/trump-jan...
# 119970  Washington_Post  https://www.washingtonpost.com/opinions/2021s-...
# 119971  Washington_Post  https://www.washingtonpost.com/national-securi...
#
#         Year
# 0       2018
# 1       2018
# 2       2018
# 3       2018
# 4       2018
# ...      ...
# 119967  2020
# 119968  2020
# 119969  2020
# 119970  2020
# 119971  2020
#
# [119972 rows x 6 columns]

# %%
#Remove failed articles (occure very frequent and are checked if they are failed or not)
checklist = Articles_WP_Clean["Text"].value_counts().reset_index()
checklist.columns = ["Text", "Count"]
checklist[checklist["Count"] > 3]

Articles_WP_Clean = Articles_WP_Clean[~Articles_WP_Clean["Text"].isin(checklist[checklist["Count"] > 3]["Text"])].reset_index(drop = True)

# %%
#Useful URLs per year
Articles_WP_Clean["Date"] = pd.to_datetime(Articles_WP_Clean['Date'], format='%d/%m/%Y')
Articles_WP_Clean["Year"] = Articles_WP_Clean['Date'].dt.year

#Unique URLs -> unique combination of date and URL
WP_year_useful_Articles_1 = Articles_WP_Clean.groupby(["News Paper","Year", "Date"])["Link"].nunique().reset_index(name='Unique_URLs_Count').groupby(["News Paper", "Year"]).sum("Unique_URLs_Count").reset_index()

#Unique URLs -> one URL on two different dates counts as one URL
WP_year_useful_Articles_2 = Articles_WP_Clean.groupby(["News Paper","Year"])["Link"].nunique().reset_index(name='Unique_URLs_Count')

# %%
WP_year_useful_Articles_1
# Out:
#         News Paper  Year  Unique_URLs_Count
# 0  Washington_Post  2016              40513
# 1  Washington_Post  2017              31232
# 2  Washington_Post  2018              21889
# 3  Washington_Post  2019              10055
# 4  Washington_Post  2020              13291

# %%
WP_year_useful_Articles_1["Unique_URLs_Count"].sum()
# Out:
# 116980

# %%
#WP_year_useful_Articles_1.to_csv("C:/Users/Boedt/OneDrive/Bureaublad/R Thesis/WP_year_useful_Articles_1", index = False)

# %%
#Compare to URLs we got in the beginning
Comparison_WP_1 = pd.merge(WP_year_URLs_1, WP_year_useful_Articles_1, on = ["News Paper", 'Year'])
Comparison_WP_1.columns = ["News Paper", "Year", "Unique_URLs_Count", "Useful_Unique_URLs_Count"]
Comparison_WP_1["Difference"] = Comparison_WP_1["Unique_URLs_Count"] - Comparison_WP_1["Useful_Unique_URLs_Count"]

# %%
Comparison_WP_1
# Out:
#         News Paper  Year  Unique_URLs_Count  Useful_Unique_URLs_Count  \
# 0  Washington_Post  2016              49756                     40513
# 1  Washington_Post  2017              50442                     31232
# 2  Washington_Post  2018              28952                     21889
# 3  Washington_Post  2019              10275                     10055
# 4  Washington_Post  2020              13753                     13291
#
#    Difference
# 0        9243
# 1       19210
# 2        7063
# 3         220
# 4         462

# %%
WP_year_useful_Articles_2
# Out:
#         News Paper  Year  Unique_URLs_Count
# 0  Washington_Post  2016              40513
# 1  Washington_Post  2017              31232
# 2  Washington_Post  2018              21889
# 3  Washington_Post  2019              10055
# 4  Washington_Post  2020              13291

# %%
WP_year_useful_Articles_2["Unique_URLs_Count"].sum()
# Out:
# 116980

# %%
#Compare to URLs we got in the beginning
Comparison_WP_2 = pd.merge(WP_year_URLs_2, WP_year_useful_Articles_2, on = ["News Paper", 'Year'])
Comparison_WP_2.columns = ["News Paper", "Year", "Unique_URLs_Count", "Useful_Unique_URLs_Count"]
Comparison_WP_2["Difference"] = Comparison_WP_2["Unique_URLs_Count"] - Comparison_WP_2["Useful_Unique_URLs_Count"]

# %%
Comparison_WP_2
# Out:
#         News Paper  Year  Unique_URLs_Count  Useful_Unique_URLs_Count  \
# 0  Washington_Post  2016              49756                     40513
# 1  Washington_Post  2017              50442                     31232
# 2  Washington_Post  2018              28952                     21889
# 3  Washington_Post  2019              10275                     10055
# 4  Washington_Post  2020              13753                     13291
#
#    Difference
# 0        9243
# 1       19210
# 2        7063
# 3         220
# 4         462
